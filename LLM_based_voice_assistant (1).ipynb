# %%
# !pip install --upgrade openai elevenlabs

# %%
from elevenlabs.client import ElevenLabs
from elevenlabs import play
from IPython.display import Audio
import openai

# %%
from openai import OpenAI

# Initialize OpenAI client with your key
os_client = OpenAI(api_key="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")

# ElevenLabs key
eleven = ElevenLabs(
    api_key="sk_816bba14faff155d13d4d722864d87ce442032973f8b155d"
)

# %%
from IPython.display import Audio

# To fix the 402 error, try using a default voice ID available on free plans
# Examples of common default IDs: 'pNInz6obpgmqS2C8E685' (Josh) or 'EXAVITQu4vr4xnSDxMaL' (Bella)

# Generate speech
audio_generator = eleven.text_to_speech.convert(
    voice_id="EXAVITQu4vr4xnSDxMaL",   # Using Bella (a common default voice)
    text="Hello, this is the Riverwood AI assistant speaking."
)

# Convert generator output to bytes
audio_bytes = b"".join(list(audio_generator))

# Play audio in Colab
Audio(audio_bytes)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_ai_response(user_input):
    # Using the new OpenAI v1.0+ syntax
    response = os_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful Riverwood Estate AI assistant who gives construction updates politely."},
            {"role": "user", "content": user_input}
        ]
    )

    return response.choices[0].message.content

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

def get_ai_response(user_input):

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful Riverwood Estate AI assistant giving construction updates."},
            {"role": "user", "content": user_input}
        ]
    )

    return response.choices[0].message.content

# %%
from IPython.display import Audio, display

def speak(text):
    """Converts text to speech using ElevenLabs and plays it in Colab."""
    print(f"AI: {text}")

    # Generate speech using the 'eleven' client you initialized earlier
    audio_generator = eleven.text_to_speech.convert(
        voice_id="EXAVITQu4vr4xnSDxMaL", # Bella (Warm/Professional voice)
        text=text
    )

    # Convert and play
    audio_bytes = b"".join(list(audio_generator))
    display(Audio(audio_bytes, autoplay=True))

# %%
from IPython.display import Audio, display

def speak(text):
    """Converts text to speech using ElevenLabs and plays it in Colab."""
    print(f"AI: {text}")

    # Generate speech using the 'eleven' client you initialized earlier
    audio_generator = eleven.text_to_speech.convert(
        voice_id="EXAVITQu4vr4xnSDxMaL", # Bella (Warm/Professional voice)
        text=text
    )

    # ADD THESE TWO LINES HERE:
    audio_bytes = b"".join(list(audio_generator))
    display(Audio(audio_bytes, autoplay=True))

# %%
# 1. AI Initiates the Call & Greet (Scenario Step 1 & 2)
greeting = "Namaste! I am your Riverwood Estate assistant. I'm calling to let you know that the internal road work at Sector 7 Kharkhauda is now 80% complete!"
speak(greeting)

# 2. AI asks a question (Scenario Step 3)
question = "Since the progress is moving fast, do you plan to visit the site this weekend?"
speak(question)

# 3. Accept User Input (Scenario Step 4)
user_response = input("Your Response: ")

# 4. Contextual AI Response (Bonus requirement)
# This sends your answer to the LLM and speaks the reply
ai_reply = get_ai_response(user_response)
speak(ai_reply)
# Out:
# AI: Namaste! I am your Riverwood Estate assistant. I'm calling to let you know that the internal road work at Sector 7 Kharkhauda is now 80% complete!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AI: Since the progress is moving fast, do you plan to visit the site this weekend?
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Your Response: yes i will come for visit
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_1787/3207884053.py in <cell line: 0>()
# ...
